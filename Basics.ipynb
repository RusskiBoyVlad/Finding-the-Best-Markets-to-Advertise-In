# %%
#Finding out the two best markets to advertise our products
#In this project we will determine the best return on investment for our coding tutorials

# %%
import pandas as pd

# %%
survey_data = pd.read_csv("2017-fCC-New-Coders-Survey-Data.csv")
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (17,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
survey_data.shape
# Out:
# (18175, 136)

# %%
"Are you already working as a software developer?","Is this your first software development job?",
"Before you got this job, how many months did you spend looking for a job?","Would you prefer to...",

"Full-Stack Web Developer","Back-End Web Developer","  Front-End Web Developer","  Mobile Developer",
"  DevOps / SysAdmin","  Data Scientist","  Quality Assurance Engineer","  User Experience Designer",
"  Product Manager","Game Developer","Information Security","Data Engineer",Other,

"When do you plan to start applying for developer jobs?",
"About how much money do you expect to earn per year at your first developer job (in US Dollars)?",
"Would you prefer to work...","Are you willing to relocate for a job?", 

freeCodeCamp,EdX,Coursera,"Khan Academy",
"Pluralsight / Code School",Codecademy,Udacity,Udemy,"Code Wars","The Odin Project",Treehouse,Lynda.com,
"Stack Overflow",W3Schools,Skillcrush,HackerRank,"Mozilla Developer Network (MDN)",Egghead.io,"CSS Tricks",Other,
"freeCodeCamp study groups",hackathons,conferences,workshops,"Startup Weekend",NodeSchool,"Women Who Code",
"Girl Develop It","Meetup.com events",RailsBridge,"Game Jam","Rails Girls","Django Girls","weekend bootcamps",
Other,"Code Newbie","The Changelog","Software Engineering Daily","JavaScript Jabber","Ruby Rogues","Shop Talk Show",
"Developer Tea","Programming Throwdown",".NET Rocks","Talk Python To Me","JavaScript Air","The Web Ahead",
"CodePen Radio","Giant Robots Smashing into Other Giant Robots","Software Engineering Radio",Other,
"MIT Open Courseware","The New Boston",freeCodeCamp,Computerphile,DevTips,"Engineered Truth",
LearnCode.Academy,CodeCourse,LevelUpTuts,funfunfunction,"Coding Tutorials 360",Coding Train (Coding Rainbow)",
"Derek Banas",Simplilearn,"Mozilla Hacks","Google Developers",Other,

"About how many hours do you spend learning each week?",
"About how many months have you been programming for?",
"Have you attended a full-time coding bootcamp?","Which one?","Have you finished yet?",
"Did you take out a loan to pay for the bootcamp?","Based on your experience, would you recommend this bootcamp to 
your friends?","Aside from university tuition, about how much money have you spent on learning to code so far 
(in US dollars)?","Start Date (UTC)","Submit Date (UTC)","Network ID"

# %%
survey_data.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo BootcampName  \
# 0  27.0               0.0             NaN                NaN          NaN
# 1  34.0               0.0             NaN                NaN          NaN
# 2  21.0               0.0             NaN                NaN          NaN
# 3  26.0               0.0             NaN                NaN          NaN
# 4  20.0               0.0             NaN                NaN          NaN
#
#    BootcampRecommend  ChildrenNumber                 CityPopulation  \
# 0                NaN             NaN            more than 1 million
# 1                NaN             NaN              less than 100,000
# 2                NaN             NaN            more than 1 million
# 3                NaN             NaN  between 100,000 and 1 million
# 4                NaN             NaN  between 100,000 and 1 million
#
#    CodeEventConferences  CodeEventDjangoGirls         ...           \
# ...

# %%
survey_data.describe()
# Out:
#                 Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# count  15367.000000      17709.000000     1069.000000        1079.000000
# mean      27.691872          0.062002        0.699719           0.305839
# std        8.559239          0.241167        0.458594           0.460975
# min        0.000000          0.000000        0.000000           0.000000
# 25%       22.000000          0.000000        0.000000           0.000000
# 50%       26.000000          0.000000        1.000000           0.000000
# 75%       32.000000          0.000000        1.000000           1.000000
# max       90.000000          1.000000        1.000000           1.000000
#
#        BootcampRecommend  ChildrenNumber  CodeEventConferences  \
# count        1073.000000     2314.000000                1609.0
# mean            0.818267        1.832325                   1.0
# std             0.385805        0.972813                   0.0
# ...

# %%
#Data can be downloaded from here https://github.com/freeCodeCamp/2017-new-coder-survey
#This dataset is a cleaned version of the questionaire collected. It's in the raw-data folder
#I'm using a ready-made data set as it has been cleaned as described on the git-hub page
#This read-made dataset includes some columns pulled from the codefreecamp statistics (eg. attendedbootcamp)

# %%
temp = survey_data["JobRoleInterest"].value_counts(normalize=True)*100
temp
# Out:
# Full-Stack Web Developer                                                                                                                                                                         11.770595
#   Front-End Web Developer                                                                                                                                                                         6.435927
#   Data Scientist                                                                                                                                                                                  2.173913
# Back-End Web Developer                                                                                                                                                                            2.030892
# ...

# %%
#There is a range of uni and duplex interests 
# Duplex interests are still representable as they can be split into singles 
# Web developemnt (total) 22%+ a few are intereseted in non web, game dev

# %%
#First we can compare how many are interested in a single vs multiple subjects

interests_no_nulls = survey_data["JobRoleInterest"].dropna()
multiple_interests = interests_no_nulls.str.split(",")

# %%
n_of_options = multiple_interests.apply(lambda x: len(x))
options_percent = n_of_options.value_counts(normalize=True) * 100
options_percent
# Out:
# 1     31.650458
# 3     15.889588
# 4     15.217391
# 5     12.042334
# 2     10.883867
# 6      6.721968
# 7      3.861556
# 8      1.759153
# 9      0.986842
# 10     0.471968
# 12     0.300343
# 11     0.185927
# 13     0.028604
# Name: JobRoleInterest, dtype: float64

# %%
web_or_mobile = interests_no_nulls.str.contains("Web Developer|Mobile Developer")
web_or_mobile.value_counts()

freq_table = web_or_mobile.value_counts(normalize=True)*100
freq_table
# Out:
# True     86.241419
# False    13.758581
# Name: JobRoleInterest, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

freq_table.plot.bar()
plt.title("What subjects are the participants interested in?", y= 1.08)
plt.ylabel("Percentage")
plt.xticks([0,1], ["Web/Mobile \ndevelopment", "Other subjects"], rotation = 0)
plt.ylim([0,100])
# Out:
# (0, 100)

# %%
#In this graph we can see that most users (86%) are intereseted in web/mobile dev therefore we should target
#these users with our adverisement

# %%
CountryLive_nona = survey_data["CountryLive"].dropna()

CountryLive_nona.value_counts(normalize=True)*100

# %%
#For advertising, I would choose USA and India as it's more likely for users from those countries to be interested
#Together they make up nearly 45% of total users

# %%
survey_data["MonthsProgramming"].replace(0,1, inplace=True)
# print(survey_data[survey_data["MonthsProgramming"] == 1])
survey_data["MoneyPerMonth"] = survey_data["MoneyForLearning"] / survey_data["MonthsProgramming"]
print(survey_data["MoneyPerMonth"].isnull().sum())
# Out:
# 1995

# %%
survey_data = survey_data[survey_data["CountryLive"].notnull()]
countries_mean = no_null.groupby("CountryLive").mean()
countries_mean['MoneyPerMonth'][['United States of America',
                            'India', 'United Kingdom',
                            'Canada']]

# %%
#As we can see, the data is surprising, as one would expect India to be lower than UK. This could be a case of an extremem outlier

# %%
#Getting rid of values above 20000 we git rid of the extreme outliers in the USA column
survey_data = survey_data[survey_data["MoneyPerMonth"] < 20000]

# %%
import seaborn as sns

only_4 = survey_data[survey_data['CountryLive'].str.contains(
    'United States of America|India|United Kingdom|Canada')]
plt.title('Money Spent Per Month Per Country\n(Distributions)',
         fontsize = 16)

sns.boxplot(y = "MoneyPerMonth", x = "CountryLive", data = only_4)
plt.ylabel('Money per month (US dollars)')
plt.xlabel('Country')
plt.xticks(range(4), ['US', 'UK', 'India', 'Canada']) # avoids tick labels overlap
plt.show()
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/seaborn/categorical.py:454: FutureWarning:
#
# remove_na is deprecated and is a private function. Do not use.

# %%
#USA is the only country with extreme outliers

# %%
survey_data = survey_data[survey_data["MoneyPerMonth"] < 20000]

# %%
india_outliers = only_4[(only_4["CountryLive"] == "United States of America")  & (only_4["MoneyPerMonth"] > 6000)]
india_outliers
# Out:
#         Age  AttendedBootcamp  BootcampFinish  BootcampLoanYesNo  \
# 718    26.0               1.0             0.0                0.0
# 1222   32.0               1.0             0.0                0.0
# 2404   22.0               1.0             1.0                1.0
# 3184   34.0               1.0             1.0                0.0
# 3930   31.0               0.0             NaN                NaN
# 5695   27.0               1.0             0.0                0.0
# 6805   46.0               1.0             1.0                1.0
# 7198   32.0               0.0             NaN                NaN
# 7505   26.0               1.0             0.0                1.0
# 9778   33.0               1.0             0.0                1.0
# 15565  23.0               0.0             NaN                NaN
# 16650  29.0               0.0             NaN                NaN
# 16997  27.0               0.0             NaN                NaN
# ...

# %%
no_bootcamp = only_4[(only_4["CountryLive"] == "United States of America")  & (only_4["MoneyPerMonth"] > 6000) & 
                      (only_4["AttendedBootcamp"] == 0)]
no_bootcamp
# Out:
# Empty DataFrame
# ...

# %%
less_than_3_months = only_4[(only_4["CountryLive"] == "United States Of America") & (only_4["MonthsProgramming"] <= 3) 
                            & (only_4["MoneyPerMonth"] < 60000)]
less_than_3_months
# Out:
# Empty DataFrame
# ...

# %%
no_bootcamp = only_4[(only_4["CountryLive"] == "United Kingdom")  & (only_4["MoneyPerMonth"] > 6000)]
#                       (only_4["AttendedBootcamp"] == 0)]
no_bootcamp
# Out:
# Empty DataFrame
# ...

# %%
less_than_3_months = only_4[(only_4["CountryLive"] == "United States Of America") & (only_4["MonthsProgramming"] <= 3) 
                            & (only_4["MoneyPerMonth"] < 60000)]
less_than_3_months
# Out:
# Empty DataFrame
# ...

# %%
only_4 = only_4.drop(less_than_3_months.index)

# %%
Canada_4500 = only_4[(only_4["CountryLive"] == "United Kingdom") & (only_4["MoneyPerMonth"] > 4500)]
Canada_4500
# Out:
# Empty DataFrame
# ...

# %%
only_4.groupby('CountryLive').mean()['MoneyPerMonth']
# Out:
# CountryLive
# Canada                      118.434054
# India                        66.526198
# United Kingdom               55.774980
# United States of America    158.919644
# Name: MoneyPerMonth, dtype: float64

# %%
sns.boxplot(y = 'MoneyPerMonth', x = 'CountryLive',
            data = only_4)
plt.title('Money Spent Per Month Per Country\n(Distributions)',
          fontsize = 16)
plt.ylabel('Money per month (US dollars)')
plt.xlabel('Country')
plt.xticks(range(4), ['US', 'UK', 'India', 'Canada']) # avoids tick labels overlap
plt.show()
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/seaborn/categorical.py:454: FutureWarning:
#
# remove_na is deprecated and is a private function. Do not use.

# %%
only_4['CountryLive'].value_counts(normalize = True) * 100
# Out:
# United States of America    68.642471
# India                       15.333417
# United Kingdom               8.765541
# Canada                       7.258571
# Name: CountryLive, dtype: float64

# %%
#The budget can be unequally between the follwing countres: USA, Canada, India. For example, we can split it this way
#USA 65%, India 20%, UK 15%. Or stick just to two countries: USA 70%, India 30%
#Canada and UK are close together, whereas USA is an obvious choice, with India being a potential, as well as UK 
#and Canada
